# %% [markdown]
# # Installation & Setup

# %% [markdown]
# ## 1. Install Seaborn
#
# Run in terminal `pip3 install seaborn`

# %%
import seaborn
seaborn.__version__
# Out:
# '0.13.2'

# %% [markdown]
# ## 2. Import Seaborn

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## 3. Load Built-in Datasets

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df = sns.load_dataset('tips')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# Matplotlib way
plt.scatter(df['total_bill'], df['tip'])
plt.xlabel('Total Bill')
plt.ylabel('Tip')
plt.title('Bill vs Tip')
plt.show()

# %%
# Seaborn way
sns.scatterplot(data=df, x='total_bill', y='tip')
plt.title('Bill vs Tip')
plt.show()

# %%
# Seaborn plot

sns.scatterplot(data=df,
                x='total_bill',
                y='tip',
                hue='sex',        # color by gender — one parameter!
                style='smoker',   # shape by smoker status
                size='size',      # dot size by party size
                palette='viridis')
plt.title("Tips Dataset — First Seaborn Plot")
plt.tight_layout()
plt.show()

# %% [markdown]
# I didnt understand this one but looks like it happened in very less efforts.
